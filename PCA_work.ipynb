# %% [markdown]
# <a href="https://colab.research.google.com/github/johnjustine5646/AML_Labs_Trisem2/blob/main/PCA_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df=pd.read_csv('/content/seeds.csv')
df.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
df['Type'].value_counts()
# Out:
# 2    68
# 1    66
# 3    65
# Name: Type, dtype: int64

# %%
df.shape
# Out:
# (199, 8)

# %%
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df,hue='Type')
plt.show()

# %%
X=df.drop(columns=['Type'])
y=df['Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state =42)

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
accuracy1=accuracy_score(y_test,y_pred)
print(f'The accuracy for model 1 is : {accuracy1}')
# Out:
# The accuracy for model 1 is : 0.9

# %%
y.value_counts()
# Out:
# 2    68
# 1    66
# 3    65
# Name: Type, dtype: int64

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# <Axes: >

# %%
scaler=StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaler.mean_
# Out:
# array([14.91874372, 14.59582915,  0.87081055,  5.64315075,  3.26553266,
#         3.69921709,  5.42065327])

# %%
sns.pairplot(X)
plt.show()

# %%
X=df.drop(columns=['Type'])
y=df['Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state =42)

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
accuracy1=accuracy_score(y_test,y_pred)
print(f'The accuracy for model 2 is : {accuracy1}')
# Out:
# The accuracy for model 2 is : 0.8833333333333333

# %%
y.value_counts()
# Out:
# 2    68
# 1    66
# 3    65
# Name: Type, dtype: int64

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# <Axes: >

# %%
pca=PCA()
pca.fit(X)
# Out:
# PCA()

# %%
pca.mean_
# Out:
# array([14.91874372, 14.59582915,  0.87081055,  5.64315075,  3.26553266,
#         3.69921709,  5.42065327])

# %%
pca.components_
# Out:
# array([[ 8.85169308e-01,  3.95839443e-01,  4.25074480e-03,
#          1.28578012e-01,  1.10984612e-01, -1.19540898e-01,
#          1.28951338e-01],
#        [ 9.36176492e-02,  5.31524997e-02, -2.98177972e-03,
#          2.85084775e-02,  8.07419729e-04,  9.90285180e-01,
#          8.32077767e-02],
#        [ 2.62533402e-01, -2.77882551e-01,  5.78406038e-02,
#         -3.96668448e-01,  3.16823362e-01,  6.58865305e-02,
#         -7.67103664e-01],
#        [-2.03441900e-01,  5.88392440e-01, -5.81051325e-02,
#          4.29298306e-01, -2.39176432e-01,  2.62037581e-02,
#         -6.05673579e-01],
#        [-1.39443945e-01,  5.72123257e-01, -5.23641346e-02,
#         -7.90540121e-01, -1.26755669e-01, -2.99359809e-03,
#          9.72559443e-02],
#        [ 2.78046562e-01, -2.92226998e-01, -4.51665532e-02,
#         -1.26721311e-01, -8.98649492e-01,  2.70061672e-03,
#         -1.07782095e-01],
#        [ 2.53797953e-02, -6.58781574e-02, -9.94217923e-01,
# ...

# %%
pca.explained_variance_
# Out:
# array([1.08516254e+01, 2.04834826e+00, 7.37914840e-02, 1.27479228e-02,
#        2.75600772e-03, 1.58425236e-03, 2.91698076e-05])

# %%
 pca.explained_variance_ratio_
# Out:
# array([8.35326268e-01, 1.57675836e-01, 5.68025183e-03, 9.81297676e-04,
#        2.12149385e-04, 1.21951096e-04, 2.24540616e-06])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state =42)

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
accuracy1=accuracy_score(y_test,y_pred)
print(f'The accuracy for model 3 is : {accuracy1}')
# Out:
# The accuracy for model 2 is : 0.9166666666666666

# %%
y.value_counts()
# Out:
# 2    68
# 1    66
# 3    65
# Name: Type, dtype: int64

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 1.   As you can see in model 1 the accuracy was 88.33333% The supervised learning model used was Decision Tree Classfier.
# 2.   Model 2 shows us that the model after being fit with Standard Scaler has bought the accuracy upto 90%.
# 3.   Model 3 shows that after performing PCA the accuracy has increased to 91.66%.
